# %% [markdown]
# # 1. Library import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from scipy.stats import kstest, skew, kurtosis

from volatility_pipeline.models import GARCHModel
from volatility_pipeline.evaluation import (
    RollingEvaluator,
    ForecastResult,
    dm_matrix,
    mcs,
    arch_mcs,
    garman_klass,
    parkinson,
    squared_returns,
)

# %% [markdown]
# # 2. Notebook variables set up

# %%
# ── Input data variables ────────────────────────────────────────────────────
TICKER          = "BZ=F"
FULL_DATA_START = "2010-01-01"
FULL_DATA_END   = "2026-05-31"

TRAIN_START = FULL_DATA_START
TRAIN_END   = "2022-06-30"
TEST_START  = "2022-07-01"
TEST_END    = FULL_DATA_END

# ── Classical econometric model specifications ───────────────────────────────
# Each tuple: (model_type, error_distribution)
# model_type:  'GARCH' | 'GJR-GARCH' | 'EGARCH' | 'APARCH' | 'FIGARCH'
# dist:        'normal' | 't' | 'ged'
GARCH_SPECS = [
    ("GARCH",     "normal"),
    ("GARCH",     "t"),
    ("GARCH",     "ged"),
    ("GJR-GARCH", "normal"),
    ("GJR-GARCH", "t"),
    ("GJR-GARCH", "ged"),
    ("EGARCH",    "normal"),
    ("EGARCH",    "t"),
    ("EGARCH",    "ged"),
    ("APARCH",    "normal"),
    ("APARCH",    "t"),
    ("APARCH",    "ged"),
    ("FIGARCH",   "normal"),
    ("FIGARCH",   "t"),
    ("FIGARCH",   "ged"),
]

# ── Out-of-sample evaluation ─────────────────────────────────────────────────
N_AHEAD     = 1   # forecast horizon (steps ahead); only 1 is currently supported
REFIT_EVERY = 10  # re-estimate model parameters every N test steps

# WINDOW_TYPE controls the estimation scheme used during out-of-sample evaluation:
#   "expanding" — recursive: each step uses all data from the start up to t
#   "sliding"   — rolling: each step uses a fixed window of len(train) obs
# For Brent, which had significant regime shifts in 2020 and 2022, sliding may
# be preferable; consider running both and comparing.
WINDOW_TYPE = "sliding"  # 'expanding' | 'sliding'

# VARIANCE_PROXY controls the realized-variance proxy used as the forecast target:
#   "garman_klass"  — Garman-Klass (1980): uses OHLC; 5-8× less noisy than r²
#   "parkinson"     — Parkinson (1980): uses High/Low only; simpler than GK
#   "squared"       — r²: noisiest, reduces DM/MCS power significantly
# Recommendation: use "garman_klass" as the primary proxy; r² for reference only.
VARIANCE_PROXY = "squared"  # 'garman_klass' | 'parkinson' | 'squared'

# ── Statistical tests ────────────────────────────────────────────────────────
TEST_LOSS = "qlike"  # loss for DM test & MCS: 'squared' | 'absolute' | 'qlike'
MCS_ALPHA = 0.05     # MCS significance level  (0.10 → 90% MCS)
DM_ALPHA  = 0.05     # Diebold-Mariano rejection threshold

# ── Reproducibility ──────────────────────────────────────────────────────────
# RANDOM_SEED is passed to every bootstrap procedure in the pipeline (custom MCS
# and arch MCS).  Change this value to verify that results are stable across
# different seeds.  All other steps (GARCH fitting, DM test, proxy calculation,
# rolling evaluation) are fully deterministic and unaffected by this setting.
#
# N_BOOT controls the number of bootstrap replications used by both MCS
# implementations.  Higher values give more stable p-values at the cost of
# runtime.  1000 is the minimum recommended; 2000 is a safe default.
RANDOM_SEED = 42
N_BOOT      = 2000

# %% [markdown]
# # 3. Import data

# %%
# Import data from Yahoo Finance (OHLC + Close needed for range-based proxies)
data   = yf.download(TICKER, start=FULL_DATA_START, end=FULL_DATA_END)
close  = data["Close"].squeeze()
open_  = data["Open"].squeeze()
high   = data["High"].squeeze()
low    = data["Low"].squeeze()

returns = np.log(close / close.shift(1)).dropna()

# Compute variance proxy on the original DatetimeIndex (before PeriodIndex conversion)
if VARIANCE_PROXY == "garman_klass":
    _proxy = garman_klass(
        open_.reindex(returns.index),
        high.reindex(returns.index),
        low.reindex(returns.index),
        close.reindex(returns.index),
    )
elif VARIANCE_PROXY == "parkinson":
    _proxy = parkinson(
        high.reindex(returns.index),
        low.reindex(returns.index),
    )
else:  # "squared"
    _proxy = squared_returns(returns)

# Convert both series to PeriodIndex for consistency with arch model indexing
returns.index = pd.PeriodIndex(returns.index, freq='D')
_proxy.index  = returns.index
variance_proxy = _proxy

print(f"Proxy: {VARIANCE_PROXY}  |  {len(variance_proxy)} observations")
print(f"  min={variance_proxy.min():.6e}  max={variance_proxy.max():.6e}  mean={variance_proxy.mean():.6e}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Proxy: squared  |  4094 observations
#   min=0.000000e+00  max=7.826649e-02  mean=5.396922e-04

# %%
# Visualize the data
plt.figure(figsize=(12, 3), dpi=150)
plt.plot(close, linewidth=0.7, color='black')
plt.title(f"{TICKER} Daily Closing Price")
plt.show()

plt.figure(figsize=(12, 3), dpi=150)
plt.plot(returns.index.to_timestamp(), returns.values, label='Daily Returns', linewidth=0.7, color='black')
plt.title(f"{TICKER} Daily Log Returns")
plt.show()

# %%
def get_stats_and_ks(series, name):
    stats = series.describe()
    ks_stat, ks_pval = kstest(series, 'norm', args=(series.mean(), series.std()))
    result = {
        'count': stats['count'],
        'mean': stats['mean'],
        'std': stats['std'],
        'min': stats['min'],
        'max': stats['max'],
        'range': stats['max'] - stats['min'],
        'skewness': skew(series),
        'kurtosis': kurtosis(series),
        'KS_stat': ks_stat,
        'KS_pval': ks_pval,
        'Name': name
    }
    return result

stats_list = [
    get_stats_and_ks(returns, "Full Returns")
]

stats_df = pd.DataFrame(stats_list).set_index('Name')
stats_df
# Out:
#                count      mean       std       min       max     range  \
# Name
# Full Returns  4094.0  0.000034  0.023234 -0.279761  0.190774  0.470536
#
#               skewness   kurtosis   KS_stat       KS_pval
# Name
# Full Returns -0.997909  15.340816  0.086771  2.872243e-27

# %% [markdown]
# # 4. Classical Econometric Models (GARCH Family)
#
# Five volatility specifications are estimated with three error distributions each (Normal, Student-t, GED), giving 15 models in total.
#
# | Spec | Description |
# |------|-------------|
# | GARCH | Standard symmetric GARCH(1,1) — Bollerslev (1986) |
# | GJR-GARCH | Asymmetric leverage effect via indicator term — Glosten et al. (1993) |
# | EGARCH | Log-variance equation, asymmetric — Nelson (1991) |
# | APARCH | Asymmetric power ARCH — Ding et al. (1993) |
# | FIGARCH | Fractionally integrated long-memory variance — Baillie et al. (1996) |
#
# ## 4.1 In-sample fit

# %%
# Split returns into train / test using the date variables set above
train_returns = returns[returns.index <= TRAIN_END]
test_returns  = returns[returns.index >= TEST_START]

print(f"Train: {train_returns.index[0]}  →  {train_returns.index[-1]}  ({len(train_returns)} obs)")
print(f"Test:  {test_returns.index[0]}  →  {test_returns.index[-1]}  ({len(test_returns)} obs)")
# Out:
# Train: 2010-01-05  →  2022-06-30  (3110 obs)
# Test:  2022-07-01  →  2026-05-29  (984 obs)

# %%
# Fit every model on training data and collect information criteria
insample_models: dict[str, GARCHModel] = {}
ic_rows = []

for model_type, dist in GARCH_SPECS:
    name = f"{model_type}-{dist.upper()}" 
    model = GARCHModel(model_type, dist)
    try:
        model.fit(train_returns)
        insample_models[name] = model
        row = model.info_criteria()
        row["Model"] = name
        ic_rows.append(row)
    except Exception as exc:
        print(f"  [WARNING] {name} failed in-sample fit: {exc}")

ic_df = (
    pd.DataFrame(ic_rows)
    .set_index("Model")
    .sort_values("BIC")
    [["LogL", "AIC", "BIC"]]
)
print(f"Fitted {len(insample_models)} / {len(GARCH_SPECS)} models")
ic_df
# Out:
# Fitted 15 / 15 models
#                          LogL           AIC           BIC
# Model
# GJR-GARCH-T      -6264.173946  12540.347891  12576.602159
# EGARCH-T         -6269.597063  12549.194126  12579.406016
# GARCH-T          -6269.988512  12549.977024  12580.188914
# APARCH-T         -6268.701121  12549.402242  12585.656510
# FIGARCH-T        -6269.000674  12550.001349  12586.255617
# GJR-GARCH-GED    -6276.601527  12565.203054  12601.457322
# EGARCH-GED       -6282.924362  12575.848724  12606.060615
# GARCH-GED        -6283.617069  12577.234138  12607.446028
# APARCH-GED       -6282.159283  12576.318566  12612.572834
# FIGARCH-GED      -6282.861130  12577.722260  12613.976528
# GJR-GARCH-NORMAL -6420.285563  12850.571125  12880.783015
# EGARCH-NORMAL    -6435.715823  12879.431646  12903.601158
# GARCH-NORMAL     -6438.946701  12885.893401  12910.062913
# APARCH-NORMAL    -6435.980475  12881.960951  12912.172841
# FIGARCH-NORMAL   -6438.721571  12887.443143  12917.655033

# %%
# In-sample conditional variance (non-annualised)
# Shows raw σ²_t as returned by each model
# PLOT_MODELS = ["GARCH-NORMAL", "GJR-GARCH-NORMAL", "EGARCH-NORMAL"]
PLOT_MODELS = [
    'GARCH-NORMAL', 'GARCH-T', 'GARCH-GED',
    'GJR-GARCH-NORMAL', 'GJR-GARCH-T', 'GJR-GARCH-GED',
    'EGARCH-NORMAL', 'EGARCH-T', 'EGARCH-GED',
    'APARCH-NORMAL', 'APARCH-T', 'APARCH-GED',
    'FIGARCH-NORMAL', 'FIGARCH-T', 'FIGARCH-GED']

fig, ax = plt.subplots(figsize=(14, 4), dpi=150)
ax.fill_between(
    train_returns.index.to_timestamp(),
    train_returns.values ** 2,
    alpha=0.15, color="gray", label="Squared returns",
)
for name in PLOT_MODELS:
    if name in insample_models:
        cv = insample_models[name].insample_variance()
        ax.plot(
            cv.index.to_timestamp(),
            cv.values,
            linewidth=0.8,
            label=name,
        )
ax.set_title(f"{TICKER} — In-sample conditional variance (non-annualised, training period)")
ax.set_ylabel("Conditional variance (σ²_t)")
ax.legend(fontsize=8)
plt.tight_layout()
plt.show()

# %%
# In-sample conditional volatility — symmetric vs asymmetric comparison
# Shows annualised conditional standard deviation: sqrt(σ²_t × 252)
# PLOT_MODELS = ["GARCH-NORMAL", "GJR-GARCH-NORMAL", "EGARCH-NORMAL"]
PLOT_MODELS = [
    'GARCH-NORMAL', 'GARCH-T', 'GARCH-GED',
    'GJR-GARCH-NORMAL', 'GJR-GARCH-T', 'GJR-GARCH-GED',
    'EGARCH-NORMAL', 'EGARCH-T', 'EGARCH-GED',
    'APARCH-NORMAL', 'APARCH-T', 'APARCH-GED',
    'FIGARCH-NORMAL', 'FIGARCH-T', 'FIGARCH-GED']

fig, ax = plt.subplots(figsize=(14, 4), dpi=150)
ax.fill_between(
    train_returns.index.to_timestamp(),
    np.sqrt(np.abs(train_returns.values) * np.sqrt(252)),
    alpha=0.15, color="gray", label="|returns| (annualised)",
)
for name in PLOT_MODELS:
    if name in insample_models:
        cv = insample_models[name].insample_variance()
        ax.plot(
            cv.index.to_timestamp(),
            np.sqrt(cv.values * 252),
            linewidth=0.8,
            label=name,
        )
ax.set_title(f"{TICKER} — In-sample conditional volatility (annualised, training period)")
ax.set_ylabel("Annualised volatility")
ax.legend(fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.2 Out-of-sample evaluation
#
# Recursive one-step-ahead forecasting: at each step *t* the model is conditioned on all returns up to *t* and produces a forecast for *t+1*. Parameters are re-estimated every `REFIT_EVERY` steps.
#
# **Window type:** `WINDOW_TYPE` — *expanding* uses all data from the start up to *t*; *sliding* keeps a fixed-width window.
#
# **Variance proxy:** `VARIANCE_PROXY` — the realized-variance series against which forecasts are evaluated. `garman_klass` (Garman-Klass 1980) uses OHLC data and is 5–8× less noisy than squared returns, which meaningfully increases the power of the DM test and MCS.

# %%
evaluator = RollingEvaluator(n_ahead=N_AHEAD, refit_every=REFIT_EVERY, window_type=WINDOW_TYPE)

# Build (factory, name) pairs — default capture avoids late-binding closure issues
garch_eval_specs = [
    (lambda t=t, d=d: GARCHModel(t, d), f"{t}-{d.upper()}")
    for t, d in GARCH_SPECS
]

garch_results: dict[str, ForecastResult] = evaluator.evaluate_many(
    garch_eval_specs,
    train_returns,
    test_returns,
    actuals_series=variance_proxy,
    verbose=True,
)
print(f"\nCompleted {len(garch_results)} models.")
print(f"Window type: {WINDOW_TYPE}  |  Proxy: {VARIANCE_PROXY}")
# Out:
# Evaluating GARCH-NORMAL...
#   [GARCH-NORMAL] re-fitted at step 0/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 10/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 20/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 30/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 40/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 50/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 60/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 70/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 80/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 90/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 100/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 110/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 120/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 130/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 140/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 150/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 160/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 170/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 180/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 190/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 200/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 210/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 220/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 230/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 240/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 250/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 260/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 270/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 280/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 290/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 300/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 310/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 320/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 330/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 340/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 350/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 360/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 370/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 380/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 390/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 400/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 410/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 420/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 430/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 440/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 450/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 460/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 470/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 480/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 490/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 500/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 510/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 520/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 530/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 540/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 550/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 560/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 570/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 580/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 590/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 600/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 610/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 620/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 630/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 640/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 650/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 660/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 670/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 680/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 690/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 700/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 710/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 720/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 730/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 740/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 750/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 760/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 770/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 780/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 790/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 800/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 810/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 820/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 830/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 840/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 850/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 860/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 870/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 880/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 890/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 900/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 910/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 920/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 930/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 940/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 950/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 960/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 970/984 (sliding)
#   [GARCH-NORMAL] re-fitted at step 980/984 (sliding)
# Evaluating GARCH-T...
#   [GARCH-T] re-fitted at step 0/984 (sliding)
#   [GARCH-T] re-fitted at step 10/984 (sliding)
#   [GARCH-T] re-fitted at step 20/984 (sliding)
#   [GARCH-T] re-fitted at step 30/984 (sliding)
#   [GARCH-T] re-fitted at step 40/984 (sliding)
#   [GARCH-T] re-fitted at step 50/984 (sliding)
#   [GARCH-T] re-fitted at step 60/984 (sliding)
#   [GARCH-T] re-fitted at step 70/984 (sliding)
#   [GARCH-T] re-fitted at step 80/984 (sliding)
#   [GARCH-T] re-fitted at step 90/984 (sliding)
#   [GARCH-T] re-fitted at step 100/984 (sliding)
#   [GARCH-T] re-fitted at step 110/984 (sliding)
#   [GARCH-T] re-fitted at step 120/984 (sliding)
#   [GARCH-T] re-fitted at step 130/984 (sliding)
#   [GARCH-T] re-fitted at step 140/984 (sliding)
#   [GARCH-T] re-fitted at step 150/984 (sliding)
#   [GARCH-T] re-fitted at step 160/984 (sliding)
#   [GARCH-T] re-fitted at step 170/984 (sliding)
#   [GARCH-T] re-fitted at step 180/984 (sliding)
#   [GARCH-T] re-fitted at step 190/984 (sliding)
#   [GARCH-T] re-fitted at step 200/984 (sliding)
#   [GARCH-T] re-fitted at step 210/984 (sliding)
#   [GARCH-T] re-fitted at step 220/984 (sliding)
#   [GARCH-T] re-fitted at step 230/984 (sliding)
#   [GARCH-T] re-fitted at step 240/984 (sliding)
#   [GARCH-T] re-fitted at step 250/984 (sliding)
#   [GARCH-T] re-fitted at step 260/984 (sliding)
#   [GARCH-T] re-fitted at step 270/984 (sliding)
#   [GARCH-T] re-fitted at step 280/984 (sliding)
#   [GARCH-T] re-fitted at step 290/984 (sliding)
#   [GARCH-T] re-fitted at step 300/984 (sliding)
#   [GARCH-T] re-fitted at step 310/984 (sliding)
#   [GARCH-T] re-fitted at step 320/984 (sliding)
#   [GARCH-T] re-fitted at step 330/984 (sliding)
#   [GARCH-T] re-fitted at step 340/984 (sliding)
#   [GARCH-T] re-fitted at step 350/984 (sliding)
#   [GARCH-T] re-fitted at step 360/984 (sliding)
#   [GARCH-T] re-fitted at step 370/984 (sliding)
#   [GARCH-T] re-fitted at step 380/984 (sliding)
#   [GARCH-T] re-fitted at step 390/984 (sliding)
#   [GARCH-T] re-fitted at step 400/984 (sliding)
#   [GARCH-T] re-fitted at step 410/984 (sliding)
#   [GARCH-T] re-fitted at step 420/984 (sliding)
#   [GARCH-T] re-fitted at step 430/984 (sliding)
#   [GARCH-T] re-fitted at step 440/984 (sliding)
#   [GARCH-T] re-fitted at step 450/984 (sliding)
#   [GARCH-T] re-fitted at step 460/984 (sliding)
#   [GARCH-T] re-fitted at step 470/984 (sliding)
#   [GARCH-T] re-fitted at step 480/984 (sliding)
#   [GARCH-T] re-fitted at step 490/984 (sliding)
#   [GARCH-T] re-fitted at step 500/984 (sliding)
#   [GARCH-T] re-fitted at step 510/984 (sliding)
#   [GARCH-T] re-fitted at step 520/984 (sliding)
#   [GARCH-T] re-fitted at step 530/984 (sliding)
#   [GARCH-T] re-fitted at step 540/984 (sliding)
#   [GARCH-T] re-fitted at step 550/984 (sliding)
#   [GARCH-T] re-fitted at step 560/984 (sliding)
#   [GARCH-T] re-fitted at step 570/984 (sliding)
#   [GARCH-T] re-fitted at step 580/984 (sliding)
#   [GARCH-T] re-fitted at step 590/984 (sliding)
#   [GARCH-T] re-fitted at step 600/984 (sliding)
#   [GARCH-T] re-fitted at step 610/984 (sliding)
#   [GARCH-T] re-fitted at step 620/984 (sliding)
#   [GARCH-T] re-fitted at step 630/984 (sliding)
#   [GARCH-T] re-fitted at step 640/984 (sliding)
#   [GARCH-T] re-fitted at step 650/984 (sliding)
#   [GARCH-T] re-fitted at step 660/984 (sliding)
#   [GARCH-T] re-fitted at step 670/984 (sliding)
#   [GARCH-T] re-fitted at step 680/984 (sliding)
#   [GARCH-T] re-fitted at step 690/984 (sliding)
#   [GARCH-T] re-fitted at step 700/984 (sliding)
#   [GARCH-T] re-fitted at step 710/984 (sliding)
#   [GARCH-T] re-fitted at step 720/984 (sliding)
#   [GARCH-T] re-fitted at step 730/984 (sliding)
#   [GARCH-T] re-fitted at step 740/984 (sliding)
#   [GARCH-T] re-fitted at step 750/984 (sliding)
#   [GARCH-T] re-fitted at step 760/984 (sliding)
#   [GARCH-T] re-fitted at step 770/984 (sliding)
#   [GARCH-T] re-fitted at step 780/984 (sliding)
#   [GARCH-T] re-fitted at step 790/984 (sliding)
#   [GARCH-T] re-fitted at step 800/984 (sliding)
#   [GARCH-T] re-fitted at step 810/984 (sliding)
#   [GARCH-T] re-fitted at step 820/984 (sliding)
#   [GARCH-T] re-fitted at step 830/984 (sliding)
#   [GARCH-T] re-fitted at step 840/984 (sliding)
#   [GARCH-T] re-fitted at step 850/984 (sliding)
#   [GARCH-T] re-fitted at step 860/984 (sliding)
#   [GARCH-T] re-fitted at step 870/984 (sliding)
#   [GARCH-T] re-fitted at step 880/984 (sliding)
#   [GARCH-T] re-fitted at step 890/984 (sliding)
#   [GARCH-T] re-fitted at step 900/984 (sliding)
#   [GARCH-T] re-fitted at step 910/984 (sliding)
#   [GARCH-T] re-fitted at step 920/984 (sliding)
#   [GARCH-T] re-fitted at step 930/984 (sliding)
#   [GARCH-T] re-fitted at step 940/984 (sliding)
#   [GARCH-T] re-fitted at step 950/984 (sliding)
#   [GARCH-T] re-fitted at step 960/984 (sliding)
#   [GARCH-T] re-fitted at step 970/984 (sliding)
#   [GARCH-T] re-fitted at step 980/984 (sliding)
# Evaluating GARCH-GED...
#   [GARCH-GED] re-fitted at step 0/984 (sliding)
#   [GARCH-GED] re-fitted at step 10/984 (sliding)
#   [GARCH-GED] re-fitted at step 20/984 (sliding)
#   [GARCH-GED] re-fitted at step 30/984 (sliding)
#   [GARCH-GED] re-fitted at step 40/984 (sliding)
#   [GARCH-GED] re-fitted at step 50/984 (sliding)
#   [GARCH-GED] re-fitted at step 60/984 (sliding)
#   [GARCH-GED] re-fitted at step 70/984 (sliding)
#   [GARCH-GED] re-fitted at step 80/984 (sliding)
#   [GARCH-GED] re-fitted at step 90/984 (sliding)
#   [GARCH-GED] re-fitted at step 100/984 (sliding)
#   [GARCH-GED] re-fitted at step 110/984 (sliding)
#   [GARCH-GED] re-fitted at step 120/984 (sliding)
#   [GARCH-GED] re-fitted at step 130/984 (sliding)
#   [GARCH-GED] re-fitted at step 140/984 (sliding)
#   [GARCH-GED] re-fitted at step 150/984 (sliding)
#   [GARCH-GED] re-fitted at step 160/984 (sliding)
#   [GARCH-GED] re-fitted at step 170/984 (sliding)
#   [GARCH-GED] re-fitted at step 180/984 (sliding)
#   [GARCH-GED] re-fitted at step 190/984 (sliding)
#   [GARCH-GED] re-fitted at step 200/984 (sliding)
#   [GARCH-GED] re-fitted at step 210/984 (sliding)
#   [GARCH-GED] re-fitted at step 220/984 (sliding)
#   [GARCH-GED] re-fitted at step 230/984 (sliding)
#   [GARCH-GED] re-fitted at step 240/984 (sliding)
#   [GARCH-GED] re-fitted at step 250/984 (sliding)
#   [GARCH-GED] re-fitted at step 260/984 (sliding)
#   [GARCH-GED] re-fitted at step 270/984 (sliding)
#   [GARCH-GED] re-fitted at step 280/984 (sliding)
#   [GARCH-GED] re-fitted at step 290/984 (sliding)
#   [GARCH-GED] re-fitted at step 300/984 (sliding)
#   [GARCH-GED] re-fitted at step 310/984 (sliding)
#   [GARCH-GED] re-fitted at step 320/984 (sliding)
#   [GARCH-GED] re-fitted at step 330/984 (sliding)
#   [GARCH-GED] re-fitted at step 340/984 (sliding)
#   [GARCH-GED] re-fitted at step 350/984 (sliding)
#   [GARCH-GED] re-fitted at step 360/984 (sliding)
#   [GARCH-GED] re-fitted at step 370/984 (sliding)
#   [GARCH-GED] re-fitted at step 380/984 (sliding)
#   [GARCH-GED] re-fitted at step 390/984 (sliding)
#   [GARCH-GED] re-fitted at step 400/984 (sliding)
#   [GARCH-GED] re-fitted at step 410/984 (sliding)
#   [GARCH-GED] re-fitted at step 420/984 (sliding)
#   [GARCH-GED] re-fitted at step 430/984 (sliding)
#   [GARCH-GED] re-fitted at step 440/984 (sliding)
#   [GARCH-GED] re-fitted at step 450/984 (sliding)
#   [GARCH-GED] re-fitted at step 460/984 (sliding)
#   [GARCH-GED] re-fitted at step 470/984 (sliding)
#   [GARCH-GED] re-fitted at step 480/984 (sliding)
#   [GARCH-GED] re-fitted at step 490/984 (sliding)
#   [GARCH-GED] re-fitted at step 500/984 (sliding)
#   [GARCH-GED] re-fitted at step 510/984 (sliding)
#   [GARCH-GED] re-fitted at step 520/984 (sliding)
#   [GARCH-GED] re-fitted at step 530/984 (sliding)
#   [GARCH-GED] re-fitted at step 540/984 (sliding)
#   [GARCH-GED] re-fitted at step 550/984 (sliding)
#   [GARCH-GED] re-fitted at step 560/984 (sliding)
#   [GARCH-GED] re-fitted at step 570/984 (sliding)
#   [GARCH-GED] re-fitted at step 580/984 (sliding)
#   [GARCH-GED] re-fitted at step 590/984 (sliding)
#   [GARCH-GED] re-fitted at step 600/984 (sliding)
#   [GARCH-GED] re-fitted at step 610/984 (sliding)
#   [GARCH-GED] re-fitted at step 620/984 (sliding)
#   [GARCH-GED] re-fitted at step 630/984 (sliding)
#   [GARCH-GED] re-fitted at step 640/984 (sliding)
#   [GARCH-GED] re-fitted at step 650/984 (sliding)
#   [GARCH-GED] re-fitted at step 660/984 (sliding)
#   [GARCH-GED] re-fitted at step 670/984 (sliding)
#   [GARCH-GED] re-fitted at step 680/984 (sliding)
#   [GARCH-GED] re-fitted at step 690/984 (sliding)
#   [GARCH-GED] re-fitted at step 700/984 (sliding)
#   [GARCH-GED] re-fitted at step 710/984 (sliding)
#   [GARCH-GED] re-fitted at step 720/984 (sliding)
#   [GARCH-GED] re-fitted at step 730/984 (sliding)
#   [GARCH-GED] re-fitted at step 740/984 (sliding)
#   [GARCH-GED] re-fitted at step 750/984 (sliding)
#   [GARCH-GED] re-fitted at step 760/984 (sliding)
#   [GARCH-GED] re-fitted at step 770/984 (sliding)
#   [GARCH-GED] re-fitted at step 780/984 (sliding)
#   [GARCH-GED] re-fitted at step 790/984 (sliding)
#   [GARCH-GED] re-fitted at step 800/984 (sliding)
#   [GARCH-GED] re-fitted at step 810/984 (sliding)
#   [GARCH-GED] re-fitted at step 820/984 (sliding)
#   [GARCH-GED] re-fitted at step 830/984 (sliding)
#   [GARCH-GED] re-fitted at step 840/984 (sliding)
#   [GARCH-GED] re-fitted at step 850/984 (sliding)
#   [GARCH-GED] re-fitted at step 860/984 (sliding)
#   [GARCH-GED] re-fitted at step 870/984 (sliding)
#   [GARCH-GED] re-fitted at step 880/984 (sliding)
#   [GARCH-GED] re-fitted at step 890/984 (sliding)
#   [GARCH-GED] re-fitted at step 900/984 (sliding)
#   [GARCH-GED] re-fitted at step 910/984 (sliding)
#   [GARCH-GED] re-fitted at step 920/984 (sliding)
#   [GARCH-GED] re-fitted at step 930/984 (sliding)
#   [GARCH-GED] re-fitted at step 940/984 (sliding)
#   [GARCH-GED] re-fitted at step 950/984 (sliding)
#   [GARCH-GED] re-fitted at step 960/984 (sliding)
#   [GARCH-GED] re-fitted at step 970/984 (sliding)
#   [GARCH-GED] re-fitted at step 980/984 (sliding)
# Evaluating GJR-GARCH-NORMAL...
#   [GJR-GARCH-NORMAL] re-fitted at step 0/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 10/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 20/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 30/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 40/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 50/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 60/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 70/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 80/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 90/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 100/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 110/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 120/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 130/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 140/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 150/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 160/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 170/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 180/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 190/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 200/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 210/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 220/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 230/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 240/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 250/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 260/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 270/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 280/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 290/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 300/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 310/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 320/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 330/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 340/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 350/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 360/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 370/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 380/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 390/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 400/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 410/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 420/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 430/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 440/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 450/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 460/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 470/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 480/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 490/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 500/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 510/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 520/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 530/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 540/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 550/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 560/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 570/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 580/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 590/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 600/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 610/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 620/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 630/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 640/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 650/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 660/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 670/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 680/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 690/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 700/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 710/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 720/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 730/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 740/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 750/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 760/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 770/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 780/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 790/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 800/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 810/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 820/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 830/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 840/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 850/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 860/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 870/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 880/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 890/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 900/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 910/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 920/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 930/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 940/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 950/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 960/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 970/984 (sliding)
#   [GJR-GARCH-NORMAL] re-fitted at step 980/984 (sliding)
# Evaluating GJR-GARCH-T...
#   [GJR-GARCH-T] re-fitted at step 0/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 10/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 20/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 30/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 40/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 50/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 60/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 70/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 80/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 90/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 100/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 110/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 120/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 130/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 140/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 150/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 160/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 170/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 180/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 190/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 200/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 210/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 220/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 230/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 240/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 250/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 260/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 270/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 280/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 290/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 300/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 310/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 320/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 330/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 340/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 350/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 360/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 370/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 380/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 390/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 400/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 410/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 420/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 430/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 440/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 450/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 460/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 470/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 480/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 490/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 500/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 510/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 520/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 530/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 540/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 550/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 560/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 570/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 580/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 590/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 600/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 610/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 620/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 630/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 640/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 650/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 660/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 670/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 680/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 690/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 700/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 710/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 720/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 730/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 740/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 750/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 760/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 770/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 780/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 790/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 800/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 810/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 820/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 830/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 840/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 850/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 860/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 870/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 880/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 890/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 900/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 910/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 920/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 930/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 940/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 950/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 960/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 970/984 (sliding)
#   [GJR-GARCH-T] re-fitted at step 980/984 (sliding)
# Evaluating GJR-GARCH-GED...
#   [GJR-GARCH-GED] re-fitted at step 0/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 10/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 20/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 30/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 40/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 50/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 60/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 70/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 80/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 90/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 100/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 110/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 120/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 130/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 140/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 150/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 160/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 170/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 180/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 190/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 200/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 210/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 220/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 230/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 240/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 250/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 260/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 270/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 280/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 290/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 300/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 310/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 320/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 330/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 340/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 350/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 360/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 370/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 380/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 390/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 400/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 410/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 420/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 430/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 440/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 450/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 460/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 470/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 480/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 490/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 500/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 510/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 520/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 530/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 540/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 550/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 560/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 570/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 580/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 590/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 600/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 610/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 620/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 630/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 640/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 650/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 660/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 670/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 680/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 690/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 700/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 710/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 720/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 730/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 740/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 750/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 760/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 770/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 780/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 790/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 800/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 810/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 820/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 830/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 840/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 850/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 860/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 870/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 880/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 890/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 900/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 910/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 920/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 930/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 940/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 950/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 960/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 970/984 (sliding)
#   [GJR-GARCH-GED] re-fitted at step 980/984 (sliding)
# Evaluating EGARCH-NORMAL...
#   [EGARCH-NORMAL] re-fitted at step 0/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 10/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 20/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 30/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 40/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 50/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 60/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 70/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 80/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 90/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 100/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 110/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 120/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 130/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 140/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 150/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 160/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 170/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 180/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 190/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 200/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 210/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 220/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 230/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 240/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 250/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 260/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 270/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 280/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 290/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 300/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 310/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 320/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 330/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 340/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 350/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 360/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 370/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 380/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 390/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 400/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 410/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 420/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 430/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 440/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 450/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 460/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 470/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 480/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 490/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 500/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 510/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 520/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 530/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 540/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 550/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 560/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 570/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 580/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 590/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 600/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 610/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 620/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 630/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 640/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 650/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 660/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 670/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 680/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 690/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 700/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 710/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 720/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 730/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 740/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 750/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 760/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 770/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 780/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 790/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 800/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 810/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 820/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 830/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 840/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 850/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 860/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 870/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 880/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 890/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 900/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 910/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 920/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 930/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 940/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 950/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 960/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 970/984 (sliding)
#   [EGARCH-NORMAL] re-fitted at step 980/984 (sliding)
# Evaluating EGARCH-T...
#   [EGARCH-T] re-fitted at step 0/984 (sliding)
#   [EGARCH-T] re-fitted at step 10/984 (sliding)
#   [EGARCH-T] re-fitted at step 20/984 (sliding)
#   [EGARCH-T] re-fitted at step 30/984 (sliding)
#   [EGARCH-T] re-fitted at step 40/984 (sliding)
#   [EGARCH-T] re-fitted at step 50/984 (sliding)
#   [EGARCH-T] re-fitted at step 60/984 (sliding)
#   [EGARCH-T] re-fitted at step 70/984 (sliding)
#   [EGARCH-T] re-fitted at step 80/984 (sliding)
#   [EGARCH-T] re-fitted at step 90/984 (sliding)
#   [EGARCH-T] re-fitted at step 100/984 (sliding)
#   [EGARCH-T] re-fitted at step 110/984 (sliding)
#   [EGARCH-T] re-fitted at step 120/984 (sliding)
#   [EGARCH-T] re-fitted at step 130/984 (sliding)
#   [EGARCH-T] re-fitted at step 140/984 (sliding)
#   [EGARCH-T] re-fitted at step 150/984 (sliding)
#   [EGARCH-T] re-fitted at step 160/984 (sliding)
#   [EGARCH-T] re-fitted at step 170/984 (sliding)
#   [EGARCH-T] re-fitted at step 180/984 (sliding)
#   [EGARCH-T] re-fitted at step 190/984 (sliding)
#   [EGARCH-T] re-fitted at step 200/984 (sliding)
#   [EGARCH-T] re-fitted at step 210/984 (sliding)
#   [EGARCH-T] re-fitted at step 220/984 (sliding)
#   [EGARCH-T] re-fitted at step 230/984 (sliding)
#   [EGARCH-T] re-fitted at step 240/984 (sliding)
#   [EGARCH-T] re-fitted at step 250/984 (sliding)
#   [EGARCH-T] re-fitted at step 260/984 (sliding)
#   [EGARCH-T] re-fitted at step 270/984 (sliding)
#   [EGARCH-T] re-fitted at step 280/984 (sliding)
#   [EGARCH-T] re-fitted at step 290/984 (sliding)
#   [EGARCH-T] re-fitted at step 300/984 (sliding)
#   [EGARCH-T] re-fitted at step 310/984 (sliding)
#   [EGARCH-T] re-fitted at step 320/984 (sliding)
#   [EGARCH-T] re-fitted at step 330/984 (sliding)
#   [EGARCH-T] re-fitted at step 340/984 (sliding)
#   [EGARCH-T] re-fitted at step 350/984 (sliding)
#   [EGARCH-T] re-fitted at step 360/984 (sliding)
#   [EGARCH-T] re-fitted at step 370/984 (sliding)
#   [EGARCH-T] re-fitted at step 380/984 (sliding)
#   [EGARCH-T] re-fitted at step 390/984 (sliding)
#   [EGARCH-T] re-fitted at step 400/984 (sliding)
#   [EGARCH-T] re-fitted at step 410/984 (sliding)
#   [EGARCH-T] re-fitted at step 420/984 (sliding)
#   [EGARCH-T] re-fitted at step 430/984 (sliding)
#   [EGARCH-T] re-fitted at step 440/984 (sliding)
#   [EGARCH-T] re-fitted at step 450/984 (sliding)
#   [EGARCH-T] re-fitted at step 460/984 (sliding)
#   [EGARCH-T] re-fitted at step 470/984 (sliding)
#   [EGARCH-T] re-fitted at step 480/984 (sliding)
#   [EGARCH-T] re-fitted at step 490/984 (sliding)
#   [EGARCH-T] re-fitted at step 500/984 (sliding)
#   [EGARCH-T] re-fitted at step 510/984 (sliding)
#   [EGARCH-T] re-fitted at step 520/984 (sliding)
#   [EGARCH-T] re-fitted at step 530/984 (sliding)
#   [EGARCH-T] re-fitted at step 540/984 (sliding)
#   [EGARCH-T] re-fitted at step 550/984 (sliding)
#   [EGARCH-T] re-fitted at step 560/984 (sliding)
#   [EGARCH-T] re-fitted at step 570/984 (sliding)
#   [EGARCH-T] re-fitted at step 580/984 (sliding)
#   [EGARCH-T] re-fitted at step 590/984 (sliding)
#   [EGARCH-T] re-fitted at step 600/984 (sliding)
#   [EGARCH-T] re-fitted at step 610/984 (sliding)
#   [EGARCH-T] re-fitted at step 620/984 (sliding)
#   [EGARCH-T] re-fitted at step 630/984 (sliding)
#   [EGARCH-T] re-fitted at step 640/984 (sliding)
#   [EGARCH-T] re-fitted at step 650/984 (sliding)
#   [EGARCH-T] re-fitted at step 660/984 (sliding)
#   [EGARCH-T] re-fitted at step 670/984 (sliding)
#   [EGARCH-T] re-fitted at step 680/984 (sliding)
#   [EGARCH-T] re-fitted at step 690/984 (sliding)
#   [EGARCH-T] re-fitted at step 700/984 (sliding)
#   [EGARCH-T] re-fitted at step 710/984 (sliding)
#   [EGARCH-T] re-fitted at step 720/984 (sliding)
#   [EGARCH-T] re-fitted at step 730/984 (sliding)
#   [EGARCH-T] re-fitted at step 740/984 (sliding)
#   [EGARCH-T] re-fitted at step 750/984 (sliding)
#   [EGARCH-T] re-fitted at step 760/984 (sliding)
#   [EGARCH-T] re-fitted at step 770/984 (sliding)
#   [EGARCH-T] re-fitted at step 780/984 (sliding)
#   [EGARCH-T] re-fitted at step 790/984 (sliding)
#   [EGARCH-T] re-fitted at step 800/984 (sliding)
#   [EGARCH-T] re-fitted at step 810/984 (sliding)
#   [EGARCH-T] re-fitted at step 820/984 (sliding)
#   [EGARCH-T] re-fitted at step 830/984 (sliding)
#   [EGARCH-T] re-fitted at step 840/984 (sliding)
#   [EGARCH-T] re-fitted at step 850/984 (sliding)
#   [EGARCH-T] re-fitted at step 860/984 (sliding)
#   [EGARCH-T] re-fitted at step 870/984 (sliding)
#   [EGARCH-T] re-fitted at step 880/984 (sliding)
#   [EGARCH-T] re-fitted at step 890/984 (sliding)
#   [EGARCH-T] re-fitted at step 900/984 (sliding)
#   [EGARCH-T] re-fitted at step 910/984 (sliding)
#   [EGARCH-T] re-fitted at step 920/984 (sliding)
#   [EGARCH-T] re-fitted at step 930/984 (sliding)
#   [EGARCH-T] re-fitted at step 940/984 (sliding)
#   [EGARCH-T] re-fitted at step 950/984 (sliding)
#   [EGARCH-T] re-fitted at step 960/984 (sliding)
#   [EGARCH-T] re-fitted at step 970/984 (sliding)
#   [EGARCH-T] re-fitted at step 980/984 (sliding)
# Evaluating EGARCH-GED...
#   [EGARCH-GED] re-fitted at step 0/984 (sliding)
#   [EGARCH-GED] re-fitted at step 10/984 (sliding)
#   [EGARCH-GED] re-fitted at step 20/984 (sliding)
#   [EGARCH-GED] re-fitted at step 30/984 (sliding)
#   [EGARCH-GED] re-fitted at step 40/984 (sliding)
#   [EGARCH-GED] re-fitted at step 50/984 (sliding)
#   [EGARCH-GED] re-fitted at step 60/984 (sliding)
#   [EGARCH-GED] re-fitted at step 70/984 (sliding)
#   [EGARCH-GED] re-fitted at step 80/984 (sliding)
#   [EGARCH-GED] re-fitted at step 90/984 (sliding)
#   [EGARCH-GED] re-fitted at step 100/984 (sliding)
#   [EGARCH-GED] re-fitted at step 110/984 (sliding)
#   [EGARCH-GED] re-fitted at step 120/984 (sliding)
#   [EGARCH-GED] re-fitted at step 130/984 (sliding)
#   [EGARCH-GED] re-fitted at step 140/984 (sliding)
#   [EGARCH-GED] re-fitted at step 150/984 (sliding)
#   [EGARCH-GED] re-fitted at step 160/984 (sliding)
#   [EGARCH-GED] re-fitted at step 170/984 (sliding)
#   [EGARCH-GED] re-fitted at step 180/984 (sliding)
#   [EGARCH-GED] re-fitted at step 190/984 (sliding)
#   [EGARCH-GED] re-fitted at step 200/984 (sliding)
#   [EGARCH-GED] re-fitted at step 210/984 (sliding)
#   [EGARCH-GED] re-fitted at step 220/984 (sliding)
#   [EGARCH-GED] re-fitted at step 230/984 (sliding)
#   [EGARCH-GED] re-fitted at step 240/984 (sliding)
#   [EGARCH-GED] re-fitted at step 250/984 (sliding)
#   [EGARCH-GED] re-fitted at step 260/984 (sliding)
#   [EGARCH-GED] re-fitted at step 270/984 (sliding)
#   [EGARCH-GED] re-fitted at step 280/984 (sliding)
#   [EGARCH-GED] re-fitted at step 290/984 (sliding)
#   [EGARCH-GED] re-fitted at step 300/984 (sliding)
#   [EGARCH-GED] re-fitted at step 310/984 (sliding)
#   [EGARCH-GED] re-fitted at step 320/984 (sliding)
#   [EGARCH-GED] re-fitted at step 330/984 (sliding)
#   [EGARCH-GED] re-fitted at step 340/984 (sliding)
#   [EGARCH-GED] re-fitted at step 350/984 (sliding)
#   [EGARCH-GED] re-fitted at step 360/984 (sliding)
#   [EGARCH-GED] re-fitted at step 370/984 (sliding)
#   [EGARCH-GED] re-fitted at step 380/984 (sliding)
#   [EGARCH-GED] re-fitted at step 390/984 (sliding)
#   [EGARCH-GED] re-fitted at step 400/984 (sliding)
#   [EGARCH-GED] re-fitted at step 410/984 (sliding)
#   [EGARCH-GED] re-fitted at step 420/984 (sliding)
#   [EGARCH-GED] re-fitted at step 430/984 (sliding)
#   [EGARCH-GED] re-fitted at step 440/984 (sliding)
#   [EGARCH-GED] re-fitted at step 450/984 (sliding)
#   [EGARCH-GED] re-fitted at step 460/984 (sliding)
#   [EGARCH-GED] re-fitted at step 470/984 (sliding)
#   [EGARCH-GED] re-fitted at step 480/984 (sliding)
#   [EGARCH-GED] re-fitted at step 490/984 (sliding)
#   [EGARCH-GED] re-fitted at step 500/984 (sliding)
#   [EGARCH-GED] re-fitted at step 510/984 (sliding)
#   [EGARCH-GED] re-fitted at step 520/984 (sliding)
#   [EGARCH-GED] re-fitted at step 530/984 (sliding)
#   [EGARCH-GED] re-fitted at step 540/984 (sliding)
#   [EGARCH-GED] re-fitted at step 550/984 (sliding)
#   [EGARCH-GED] re-fitted at step 560/984 (sliding)
#   [EGARCH-GED] re-fitted at step 570/984 (sliding)
#   [EGARCH-GED] re-fitted at step 580/984 (sliding)
#   [EGARCH-GED] re-fitted at step 590/984 (sliding)
#   [EGARCH-GED] re-fitted at step 600/984 (sliding)
#   [EGARCH-GED] re-fitted at step 610/984 (sliding)
#   [EGARCH-GED] re-fitted at step 620/984 (sliding)
#   [EGARCH-GED] re-fitted at step 630/984 (sliding)
#   [EGARCH-GED] re-fitted at step 640/984 (sliding)
#   [EGARCH-GED] re-fitted at step 650/984 (sliding)
#   [EGARCH-GED] re-fitted at step 660/984 (sliding)
#   [EGARCH-GED] re-fitted at step 670/984 (sliding)
#   [EGARCH-GED] re-fitted at step 680/984 (sliding)
#   [EGARCH-GED] re-fitted at step 690/984 (sliding)
#   [EGARCH-GED] re-fitted at step 700/984 (sliding)
#   [EGARCH-GED] re-fitted at step 710/984 (sliding)
#   [EGARCH-GED] re-fitted at step 720/984 (sliding)
#   [EGARCH-GED] re-fitted at step 730/984 (sliding)
#   [EGARCH-GED] re-fitted at step 740/984 (sliding)
#   [EGARCH-GED] re-fitted at step 750/984 (sliding)
#   [EGARCH-GED] re-fitted at step 760/984 (sliding)
#   [EGARCH-GED] re-fitted at step 770/984 (sliding)
#   [EGARCH-GED] re-fitted at step 780/984 (sliding)
#   [EGARCH-GED] re-fitted at step 790/984 (sliding)
#   [EGARCH-GED] re-fitted at step 800/984 (sliding)
#   [EGARCH-GED] re-fitted at step 810/984 (sliding)
#   [EGARCH-GED] re-fitted at step 820/984 (sliding)
#   [EGARCH-GED] re-fitted at step 830/984 (sliding)
#   [EGARCH-GED] re-fitted at step 840/984 (sliding)
#   [EGARCH-GED] re-fitted at step 850/984 (sliding)
#   [EGARCH-GED] re-fitted at step 860/984 (sliding)
#   [EGARCH-GED] re-fitted at step 870/984 (sliding)
#   [EGARCH-GED] re-fitted at step 880/984 (sliding)
#   [EGARCH-GED] re-fitted at step 890/984 (sliding)
#   [EGARCH-GED] re-fitted at step 900/984 (sliding)
#   [EGARCH-GED] re-fitted at step 910/984 (sliding)
#   [EGARCH-GED] re-fitted at step 920/984 (sliding)
#   [EGARCH-GED] re-fitted at step 930/984 (sliding)
#   [EGARCH-GED] re-fitted at step 940/984 (sliding)
#   [EGARCH-GED] re-fitted at step 950/984 (sliding)
#   [EGARCH-GED] re-fitted at step 960/984 (sliding)
#   [EGARCH-GED] re-fitted at step 970/984 (sliding)
#   [EGARCH-GED] re-fitted at step 980/984 (sliding)
# Evaluating APARCH-NORMAL...
#   [APARCH-NORMAL] re-fitted at step 0/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 10/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 20/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 30/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 40/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 50/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 60/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 70/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 80/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 90/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 100/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 110/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 120/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 130/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 140/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 150/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 160/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 170/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 180/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 190/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 200/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 210/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 220/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 230/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 240/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 250/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 260/984 (sliding)
#   [APARCH-NORMAL] re-fitted at step 270/984 (sliding)
# ...
#   [APARCH-GED] re-fitted at step 930/984 (sliding)
#   [APARCH-GED] re-fitted at step 940/984 (sliding)
#   [APARCH-GED] re-fitted at step 950/984 (sliding)
#   [APARCH-GED] re-fitted at step 960/984 (sliding)
#   [APARCH-GED] re-fitted at step 970/984 (sliding)
#   [APARCH-GED] re-fitted at step 980/984 (sliding)
# Evaluating FIGARCH-NORMAL...
#   [FIGARCH-NORMAL] re-fitted at step 0/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 10/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 20/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 30/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 40/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 50/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 60/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 70/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 80/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 90/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 100/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 110/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 120/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 130/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 140/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 150/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 160/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 170/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 180/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 190/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 200/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 210/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 220/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 230/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 240/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 250/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 260/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 270/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 280/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 290/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 300/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 310/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 320/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 330/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 340/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 350/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 360/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 370/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 380/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 390/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 400/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 410/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 420/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 430/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 440/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 450/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 460/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 470/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 480/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 490/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 500/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 510/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 520/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 530/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 540/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 550/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 560/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 570/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 580/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 590/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 600/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 610/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 620/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 630/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 640/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 650/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 660/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 670/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 680/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 690/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 700/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 710/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 720/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 730/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 740/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 750/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 760/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 770/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 780/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 790/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 800/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 810/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 820/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 830/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 840/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 850/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 860/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 870/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 880/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 890/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 900/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 910/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 920/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 930/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 940/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 950/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 960/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 970/984 (sliding)
#   [FIGARCH-NORMAL] re-fitted at step 980/984 (sliding)
# Evaluating FIGARCH-T...
#   [FIGARCH-T] re-fitted at step 0/984 (sliding)
#   [FIGARCH-T] re-fitted at step 10/984 (sliding)
#   [FIGARCH-T] re-fitted at step 20/984 (sliding)
#   [FIGARCH-T] re-fitted at step 30/984 (sliding)
#   [FIGARCH-T] re-fitted at step 40/984 (sliding)
#   [FIGARCH-T] re-fitted at step 50/984 (sliding)
#   [FIGARCH-T] re-fitted at step 60/984 (sliding)
#   [FIGARCH-T] re-fitted at step 70/984 (sliding)
#   [FIGARCH-T] re-fitted at step 80/984 (sliding)
#   [FIGARCH-T] re-fitted at step 90/984 (sliding)
#   [FIGARCH-T] re-fitted at step 100/984 (sliding)
#   [FIGARCH-T] re-fitted at step 110/984 (sliding)
#   [FIGARCH-T] re-fitted at step 120/984 (sliding)
#   [FIGARCH-T] re-fitted at step 130/984 (sliding)
#   [FIGARCH-T] re-fitted at step 140/984 (sliding)
#   [FIGARCH-T] re-fitted at step 150/984 (sliding)
#   [FIGARCH-T] re-fitted at step 160/984 (sliding)
#   [FIGARCH-T] re-fitted at step 170/984 (sliding)
#   [FIGARCH-T] re-fitted at step 180/984 (sliding)
#   [FIGARCH-T] re-fitted at step 190/984 (sliding)
#   [FIGARCH-T] re-fitted at step 200/984 (sliding)
#   [FIGARCH-T] re-fitted at step 210/984 (sliding)
#   [FIGARCH-T] re-fitted at step 220/984 (sliding)
#   [FIGARCH-T] re-fitted at step 230/984 (sliding)
#   [FIGARCH-T] re-fitted at step 240/984 (sliding)
#   [FIGARCH-T] re-fitted at step 250/984 (sliding)
#   [FIGARCH-T] re-fitted at step 260/984 (sliding)
#   [FIGARCH-T] re-fitted at step 270/984 (sliding)
#   [FIGARCH-T] re-fitted at step 280/984 (sliding)
#   [FIGARCH-T] re-fitted at step 290/984 (sliding)
#   [FIGARCH-T] re-fitted at step 300/984 (sliding)
#   [FIGARCH-T] re-fitted at step 310/984 (sliding)
#   [FIGARCH-T] re-fitted at step 320/984 (sliding)
#   [FIGARCH-T] re-fitted at step 330/984 (sliding)
#   [FIGARCH-T] re-fitted at step 340/984 (sliding)
#   [FIGARCH-T] re-fitted at step 350/984 (sliding)
#   [FIGARCH-T] re-fitted at step 360/984 (sliding)
#   [FIGARCH-T] re-fitted at step 370/984 (sliding)
#   [FIGARCH-T] re-fitted at step 380/984 (sliding)
#   [FIGARCH-T] re-fitted at step 390/984 (sliding)
#   [FIGARCH-T] re-fitted at step 400/984 (sliding)
#   [FIGARCH-T] re-fitted at step 410/984 (sliding)
#   [FIGARCH-T] re-fitted at step 420/984 (sliding)
#   [FIGARCH-T] re-fitted at step 430/984 (sliding)
#   [FIGARCH-T] re-fitted at step 440/984 (sliding)
#   [FIGARCH-T] re-fitted at step 450/984 (sliding)
#   [FIGARCH-T] re-fitted at step 460/984 (sliding)
#   [FIGARCH-T] re-fitted at step 470/984 (sliding)
#   [FIGARCH-T] re-fitted at step 480/984 (sliding)
#   [FIGARCH-T] re-fitted at step 490/984 (sliding)
#   [FIGARCH-T] re-fitted at step 500/984 (sliding)
#   [FIGARCH-T] re-fitted at step 510/984 (sliding)
#   [FIGARCH-T] re-fitted at step 520/984 (sliding)
#   [FIGARCH-T] re-fitted at step 530/984 (sliding)
#   [FIGARCH-T] re-fitted at step 540/984 (sliding)
#   [FIGARCH-T] re-fitted at step 550/984 (sliding)
#   [FIGARCH-T] re-fitted at step 560/984 (sliding)
#   [FIGARCH-T] re-fitted at step 570/984 (sliding)
#   [FIGARCH-T] re-fitted at step 580/984 (sliding)
#   [FIGARCH-T] re-fitted at step 590/984 (sliding)
#   [FIGARCH-T] re-fitted at step 600/984 (sliding)
#   [FIGARCH-T] re-fitted at step 610/984 (sliding)
#   [FIGARCH-T] re-fitted at step 620/984 (sliding)
#   [FIGARCH-T] re-fitted at step 630/984 (sliding)
#   [FIGARCH-T] re-fitted at step 640/984 (sliding)
#   [FIGARCH-T] re-fitted at step 650/984 (sliding)
#   [FIGARCH-T] re-fitted at step 660/984 (sliding)
#   [FIGARCH-T] re-fitted at step 670/984 (sliding)
#   [FIGARCH-T] re-fitted at step 680/984 (sliding)
#   [FIGARCH-T] re-fitted at step 690/984 (sliding)
#   [FIGARCH-T] re-fitted at step 700/984 (sliding)
#   [FIGARCH-T] re-fitted at step 710/984 (sliding)
#   [FIGARCH-T] re-fitted at step 720/984 (sliding)
#   [FIGARCH-T] re-fitted at step 730/984 (sliding)
#   [FIGARCH-T] re-fitted at step 740/984 (sliding)
#   [FIGARCH-T] re-fitted at step 750/984 (sliding)
#   [FIGARCH-T] re-fitted at step 760/984 (sliding)
#   [FIGARCH-T] re-fitted at step 770/984 (sliding)
#   [FIGARCH-T] re-fitted at step 780/984 (sliding)
#   [FIGARCH-T] re-fitted at step 790/984 (sliding)
#   [FIGARCH-T] re-fitted at step 800/984 (sliding)
#   [FIGARCH-T] re-fitted at step 810/984 (sliding)
#   [FIGARCH-T] re-fitted at step 820/984 (sliding)
#   [FIGARCH-T] re-fitted at step 830/984 (sliding)
#   [FIGARCH-T] re-fitted at step 840/984 (sliding)
#   [FIGARCH-T] re-fitted at step 850/984 (sliding)
#   [FIGARCH-T] re-fitted at step 860/984 (sliding)
#   [FIGARCH-T] re-fitted at step 870/984 (sliding)
#   [FIGARCH-T] re-fitted at step 880/984 (sliding)
#   [FIGARCH-T] re-fitted at step 890/984 (sliding)
#   [FIGARCH-T] re-fitted at step 900/984 (sliding)
#   [FIGARCH-T] re-fitted at step 910/984 (sliding)
#   [FIGARCH-T] re-fitted at step 920/984 (sliding)
#   [FIGARCH-T] re-fitted at step 930/984 (sliding)
#   [FIGARCH-T] re-fitted at step 940/984 (sliding)
#   [FIGARCH-T] re-fitted at step 950/984 (sliding)
#   [FIGARCH-T] re-fitted at step 960/984 (sliding)
#   [FIGARCH-T] re-fitted at step 970/984 (sliding)
#   [FIGARCH-T] re-fitted at step 980/984 (sliding)
# Evaluating FIGARCH-GED...
#   [FIGARCH-GED] re-fitted at step 0/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 10/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 20/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 30/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 40/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 50/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 60/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 70/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 80/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 90/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 100/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 110/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 120/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 130/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 140/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 150/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 160/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 170/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 180/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 190/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 200/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 210/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 220/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 230/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 240/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 250/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 260/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 270/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 280/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 290/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 300/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 310/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 320/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 330/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 340/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 350/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 360/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 370/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 380/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 390/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 400/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 410/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 420/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 430/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 440/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 450/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 460/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 470/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 480/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 490/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 500/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 510/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 520/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 530/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 540/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 550/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 560/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 570/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 580/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 590/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 600/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 610/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 620/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 630/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 640/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 650/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 660/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 670/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 680/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 690/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 700/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 710/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 720/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 730/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 740/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 750/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 760/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 770/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 780/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 790/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 800/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 810/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 820/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 830/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 840/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 850/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 860/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 870/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 880/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 890/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 900/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 910/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 920/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 930/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 940/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 950/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 960/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 970/984 (sliding)
#   [FIGARCH-GED] re-fitted at step 980/984 (sliding)
#
# Completed 15 models.
# Window type: sliding  |  Proxy: squared

# %%
# Out-of-sample metrics table — ranked by RMSE
metrics_df = (
    pd.DataFrame({name: r.metrics() for name, r in garch_results.items()})
    .T
    .sort_values("RMSE")
    [["RMSE", "MAE", "MSE", "QLIKE"]]
)
metrics_df
# Out:
#                       RMSE       MAE       MSE     QLIKE
# EGARCH-GED        0.001423  0.000592  0.000002 -6.564395
# EGARCH-T          0.001424  0.000598  0.000002 -6.573526
# EGARCH-NORMAL     0.001425  0.000600  0.000002 -6.551815
# APARCH-T          0.001431  0.000594  0.000002 -6.572266
# APARCH-GED        0.001431  0.000594  0.000002 -6.562982
# APARCH-NORMAL     0.001436  0.000604  0.000002 -6.555289
# GARCH-GED         0.001439  0.000601  0.000002 -6.561782
# GARCH-T           0.001441  0.000607  0.000002 -6.572105
# GARCH-NORMAL      0.001443  0.000610  0.000002 -6.554427
# FIGARCH-GED       0.001444  0.000606  0.000002 -6.552959
# FIGARCH-T         0.001444  0.000607  0.000002 -6.561069
# GJR-GARCH-GED     0.001448  0.000608  0.000002 -6.544644
# GJR-GARCH-T       0.001449  0.000613  0.000002 -6.557392
# FIGARCH-NORMAL    0.001451  0.000619  0.000002 -6.548813
# GJR-GARCH-NORMAL  0.001455  0.000620  0.000002 -6.530005

# %%
# Forecast vs realized — best model by RMSE (non-annualised)
# Shows raw variance: σ²_t forecast vs squared-return proxy
best_name = metrics_df.index[0]
r = garch_results[best_name]

fig, axes = plt.subplots(2, 1, figsize=(14, 6), dpi=150, sharex=True)

ax0, ax1 = axes
ax0.plot(
    r.actuals.index.to_timestamp(),
    r.actuals.values,
    color="black", linewidth=0.6, label="Realized variance proxy (r²_t)",
)
ax0.plot(
    r.forecasts.index.to_timestamp(),
    r.forecasts.values,
    color="steelblue", linewidth=0.9, label=f"{best_name} forecast",
)
ax0.set_title(f"{TICKER} — Out-of-sample 1-step-ahead forecast (best model: {best_name})")
ax0.set_ylabel("Conditional variance (σ²_t)")
ax0.legend(fontsize=8)

ax1.plot(
    r.errors.index.to_timestamp(),
    r.errors.values,
    color="firebrick", linewidth=0.6,
)
ax1.axhline(0, color="black", linewidth=0.5, linestyle="--")
ax1.set_title("Forecast error (forecast − realized variance proxy)")
ax1.set_ylabel("Error")

plt.tight_layout()
plt.show()

# %%
# Forecast vs realized — best model by RMSE
best_name = metrics_df.index[0]
r = garch_results[best_name]

fig, axes = plt.subplots(2, 1, figsize=(14, 6), dpi=150, sharex=True)

ax0, ax1 = axes
ax0.plot(
    r.actuals.index.to_timestamp(),
    np.sqrt(r.actuals.values * 252),
    color="black", linewidth=0.6, label="Realized vol proxy (annualised)",
)
ax0.plot(
    r.forecasts.index.to_timestamp(),
    np.sqrt(r.forecasts.values * 252),
    color="steelblue", linewidth=0.9, label=f"{best_name} forecast",
)
ax0.set_title(f"{TICKER} — Out-of-sample 1-step-ahead forecast (best model: {best_name})")
ax0.set_ylabel("Annualised volatility")
ax0.legend(fontsize=8)

ax1.plot(
    r.errors.index.to_timestamp(),
    r.errors.values,
    color="firebrick", linewidth=0.6,
)
ax1.axhline(0, color="black", linewidth=0.5, linestyle="--")
ax1.set_title("Forecast error (forecast − realized variance proxy)")
ax1.set_ylabel("Error")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Statistical Tests
#
# ## 5.1 Diebold-Mariano Test (HLN correction)
#
# Pairwise test of equal predictive accuracy (Harvey, Leybourne & Newbold 1997).
# H₀: models *i* and *j* have equal expected loss.
# Negative MDM statistic → row model has lower loss than column model.
# p-values are two-sided from a *t*(T−1) distribution.

# %%
dm_stat_df, dm_pval_df = dm_matrix(garch_results, h=N_AHEAD, loss=TEST_LOSS)

print("MDM statistics (upper triangle):")
dm_stat_df.round(3)
# Out:
# MDM statistics (upper triangle):
#                   GARCH-NORMAL  GARCH-T  GARCH-GED  GJR-GARCH-NORMAL  \
# GARCH-NORMAL               NaN    3.474      2.782            -3.315
# GARCH-T                    NaN      NaN     -3.089            -4.248
# GARCH-GED                  NaN      NaN        NaN            -4.260
# GJR-GARCH-NORMAL           NaN      NaN        NaN               NaN
# GJR-GARCH-T                NaN      NaN        NaN               NaN
# GJR-GARCH-GED              NaN      NaN        NaN               NaN
# EGARCH-NORMAL              NaN      NaN        NaN               NaN
# EGARCH-T                   NaN      NaN        NaN               NaN
# EGARCH-GED                 NaN      NaN        NaN               NaN
# APARCH-NORMAL              NaN      NaN        NaN               NaN
# APARCH-T                   NaN      NaN        NaN               NaN
# APARCH-GED                 NaN      NaN        NaN               NaN
# FIGARCH-NORMAL             NaN      NaN        NaN               NaN
# FIGARCH-T                  NaN      NaN        NaN               NaN
# FIGARCH-GED                NaN      NaN        NaN               NaN
#
#                   GJR-GARCH-T  GJR-GARCH-GED  EGARCH-NORMAL  EGARCH-T  \
# GARCH-NORMAL            0.428         -1.391         -0.206     1.562
# GARCH-T                -2.669         -3.437         -1.441     0.122
# GARCH-GED              -0.833         -2.825         -0.738     0.944
# GJR-GARCH-NORMAL        4.258          4.608          1.622     2.953
# GJR-GARCH-T               NaN         -3.440         -0.426     1.353
# GJR-GARCH-GED             NaN            NaN          0.539     2.116
# EGARCH-NORMAL             NaN            NaN            NaN     3.822
# EGARCH-T                  NaN            NaN            NaN       NaN
# EGARCH-GED                NaN            NaN            NaN       NaN
# APARCH-NORMAL             NaN            NaN            NaN       NaN
# APARCH-T                  NaN            NaN            NaN       NaN
# APARCH-GED                NaN            NaN            NaN       NaN
# FIGARCH-NORMAL            NaN            NaN            NaN       NaN
# FIGARCH-T                 NaN            NaN            NaN       NaN
# FIGARCH-GED               NaN            NaN            NaN       NaN
#
#                   EGARCH-GED  APARCH-NORMAL  APARCH-T  APARCH-GED  \
# GARCH-NORMAL           0.855          0.217     4.097       2.260
# GARCH-T               -0.627         -2.196     0.034      -1.433
# GARCH-GED              0.215         -1.109     2.335       0.256
# GJR-GARCH-NORMAL       2.590          3.076     4.549       4.196
# GJR-GARCH-T            0.594         -0.245     2.218       0.788
# GJR-GARCH-GED          1.565          1.265     3.406       2.509
# EGARCH-NORMAL          4.558          0.369     2.018       1.183
# EGARCH-T              -2.738         -1.848    -0.148      -1.136
# EGARCH-GED               NaN         -1.047     0.932      -0.170
# APARCH-NORMAL            NaN            NaN     4.268       3.576
# APARCH-T                 NaN            NaN       NaN      -3.751
# APARCH-GED               NaN            NaN       NaN         NaN
# FIGARCH-NORMAL           NaN            NaN       NaN         NaN
# FIGARCH-T                NaN            NaN       NaN         NaN
# FIGARCH-GED              NaN            NaN       NaN         NaN
#
#                   FIGARCH-NORMAL  FIGARCH-T  FIGARCH-GED
# GARCH-NORMAL              -0.593      0.665       -0.141
# GARCH-T                   -1.825     -0.888       -1.418
# GARCH-GED                 -1.124     -0.061       -0.717
# GJR-GARCH-NORMAL           1.348      2.086        1.566
# GJR-GARCH-T               -0.578      0.247       -0.285
# GJR-GARCH-GED              0.283      1.075        0.541
# EGARCH-NORMAL             -0.219      0.649        0.079
# EGARCH-T                  -1.749     -0.903       -1.392
# EGARCH-GED                -1.173     -0.248       -0.821
# APARCH-NORMAL             -0.828      0.672       -0.265
# APARCH-T                  -2.389     -1.162       -1.838
# APARCH-GED                -1.550     -0.200       -1.012
# FIGARCH-NORMAL               NaN      4.285        2.238
# FIGARCH-T                    NaN        NaN       -3.492
# FIGARCH-GED                  NaN        NaN          NaN

# %%
print("DM p-values (upper triangle) — highlighted cells: p < DM_ALPHA")
dm_pval_df.round(4).style.map(
    lambda v: "background-color: #c8e6c9; font-weight: bold"
    if (not pd.isna(v) and v < DM_ALPHA)
    else "",
)
# Out:
# DM p-values (upper triangle) — highlighted cells: p < DM_ALPHA
# <style type="text/css">
# #T_6889b_row0_col1, #T_6889b_row0_col2, #T_6889b_row0_col3, #T_6889b_row0_col10, #T_6889b_row0_col11, #T_6889b_row1_col2, #T_6889b_row1_col3, #T_6889b_row1_col4, #T_6889b_row1_col5, #T_6889b_row1_col9, #T_6889b_row2_col3, #T_6889b_row2_col5, #T_6889b_row2_col10, #T_6889b_row3_col4, #T_6889b_row3_col5, #T_6889b_row3_col7, #T_6889b_row3_col8, #T_6889b_row3_col9, #T_6889b_row3_col10, #T_6889b_row3_col11, #T_6889b_row3_col13, #T_6889b_row4_col5, #T_6889b_row4_col10, #T_6889b_row5_col7, #T_6889b_row5_col10, #T_6889b_row5_col11, #T_6889b_row6_col7, #T_6889b_row6_col8, #T_6889b_row6_col10, #T_6889b_row7_col8, #T_6889b_row9_col10, #T_6889b_row9_col11, #T_6889b_row10_col11, #T_6889b_row10_col12, #T_6889b_row12_col13, #T_6889b_row12_col14, #T_6889b_row13_col14 {
#   background-color: #c8e6c9;
#   font-weight: bold;
# }
# </style>
# <table id="T_6889b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6889b_level0_col0" class="col_heading level0 col0" >GARCH-NORMAL</th>
#       <th id="T_6889b_level0_col1" class="col_heading level0 col1" >GARCH-T</th>
#       <th id="T_6889b_level0_col2" class="col_heading level0 col2" >GARCH-GED</th>
#       <th id="T_6889b_level0_col3" class="col_heading level0 col3" >GJR-GARCH-NORMAL</th>
#       <th id="T_6889b_level0_col4" class="col_heading level0 col4" >GJR-GARCH-T</th>
#       <th id="T_6889b_level0_col5" class="col_heading level0 col5" >GJR-GARCH-GED</th>
#       <th id="T_6889b_level0_col6" class="col_heading level0 col6" >EGARCH-NORMAL</th>
#       <th id="T_6889b_level0_col7" class="col_heading level0 col7" >EGARCH-T</th>
#       <th id="T_6889b_level0_col8" class="col_heading level0 col8" >EGARCH-GED</th>
#       <th id="T_6889b_level0_col9" class="col_heading level0 col9" >APARCH-NORMAL</th>
#       <th id="T_6889b_level0_col10" class="col_heading level0 col10" >APARCH-T</th>
#       <th id="T_6889b_level0_col11" class="col_heading level0 col11" >APARCH-GED</th>
#       <th id="T_6889b_level0_col12" class="col_heading level0 col12" >FIGARCH-NORMAL</th>
#       <th id="T_6889b_level0_col13" class="col_heading level0 col13" >FIGARCH-T</th>
#       <th id="T_6889b_level0_col14" class="col_heading level0 col14" >FIGARCH-GED</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6889b_level0_row0" class="row_heading level0 row0" >GARCH-NORMAL</th>
#       <td id="T_6889b_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_6889b_row0_col1" class="data row0 col1" >0.000500</td>
#       <td id="T_6889b_row0_col2" class="data row0 col2" >0.005500</td>
#       <td id="T_6889b_row0_col3" class="data row0 col3" >0.000900</td>
#       <td id="T_6889b_row0_col4" class="data row0 col4" >0.668600</td>
#       <td id="T_6889b_row0_col5" class="data row0 col5" >0.164600</td>
#       <td id="T_6889b_row0_col6" class="data row0 col6" >0.837000</td>
#       <td id="T_6889b_row0_col7" class="data row0 col7" >0.118600</td>
#       <td id="T_6889b_row0_col8" class="data row0 col8" >0.392600</td>
#       <td id="T_6889b_row0_col9" class="data row0 col9" >0.828200</td>
#       <td id="T_6889b_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_6889b_row0_col11" class="data row0 col11" >0.024000</td>
#       <td id="T_6889b_row0_col12" class="data row0 col12" >0.553600</td>
#       <td id="T_6889b_row0_col13" class="data row0 col13" >0.506400</td>
#       <td id="T_6889b_row0_col14" class="data row0 col14" >0.887600</td>
#     </tr>
#     <tr>
#       <th id="T_6889b_level0_row1" class="row_heading level0 row1" >GARCH-T</th>
#       <td id="T_6889b_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_6889b_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_6889b_row1_col2" class="data row1 col2" >0.002100</td>
#       <td id="T_6889b_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_6889b_row1_col4" class="data row1 col4" >0.007700</td>
#       <td id="T_6889b_row1_col5" class="data row1 col5" >0.000600</td>
#       <td id="T_6889b_row1_col6" class="data row1 col6" >0.150000</td>
#       <td id="T_6889b_row1_col7" class="data row1 col7" >0.903200</td>
#       <td id="T_6889b_row1_col8" class="data row1 col8" >0.530700</td>
#       <td id="T_6889b_row1_col9" class="data row1 col9" >0.028400</td>
#       <td id="T_6889b_row1_col10" class="data row1 col10" >0.973200</td>
#       <td id="T_6889b_row1_col11" class="data row1 col11" >0.152300</td>
#       <td id="T_6889b_row1_col12" class="data row1 col12" >0.068200</td>
#       <td id="T_6889b_row1_col13" class="data row1 col13" >0.374800</td>
#       <td id="T_6889b_row1_col14" class="data row1 col14" >0.156500</td>
#     </tr>
#     <tr>
#       <th id="T_6889b_level0_row2" class="row_heading level0 row2" >GARCH-GED</th>
#       <td id="T_6889b_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_6889b_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_6889b_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_6889b_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_6889b_row2_col4" class="data row2 col4" >0.404900</td>
#       <td id="T_6889b_row2_col5" class="data row2 col5" >0.004800</td>
#       <td id="T_6889b_row2_col6" class="data row2 col6" >0.460700</td>
#       <td id="T_6889b_row2_col7" class="data row2 col7" >0.345500</td>
#       <td id="T_6889b_row2_col8" class="data row2 col8" >0.829800</td>
#       <td id="T_6889b_row2_col9" class="data row2 col9" >0.267700</td>
#       <td id="T_6889b_row2_col10" class="data row2 col10" >0.019700</td>
#       <td id="T_6889b_row2_col11" class="data row2 col11" >0.798100</td>
#       <td id="T_6889b_row2_col12" class="data row2 col12" >0.261200</td>
#       <td id="T_6889b_row2_col13" class="data row2 col13" >0.951600</td>
#       <td id="T_6889b_row2_col14" class="data row2 col14" >0.473400</td>
#     </tr>
#     <tr>
#       <th id="T_6889b_level0_row3" class="row_heading level0 row3" >GJR-GARCH-NORMAL</th>
#       <td id="T_6889b_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_6889b_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_6889b_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_6889b_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_6889b_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_6889b_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_6889b_row3_col6" class="data row3 col6" >0.105100</td>
#       <td id="T_6889b_row3_col7" class="data row3 col7" >0.003200</td>
#       <td id="T_6889b_row3_col8" class="data row3 col8" >0.009700</td>
#       <td id="T_6889b_row3_col9" class="data row3 col9" >0.002200</td>
#       <td id="T_6889b_row3_col10" class="data row3 col10" >0.000000</td>
#       <td id="T_6889b_row3_col11" class="data row3 col11" >0.000000</td>
#       <td id="T_6889b_row3_col12" class="data row3 col12" >0.178100</td>
#       <td id="T_6889b_row3_col13" class="data row3 col13" >0.037200</td>
#       <td id="T_6889b_row3_col14" class="data row3 col14" >0.117800</td>
#     </tr>
#     <tr>
#       <th id="T_6889b_level0_row4" class="row_heading level0 row4" >GJR-GARCH-T</th>
#       <td id="T_6889b_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_6889b_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_6889b_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_6889b_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_6889b_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_6889b_row4_col5" class="data row4 col5" >0.000600</td>
#       <td id="T_6889b_row4_col6" class="data row4 col6" >0.670100</td>
#       <td id="T_6889b_row4_col7" class="data row4 col7" >0.176300</td>
#       <td id="T_6889b_row4_col8" class="data row4 col8" >0.552600</td>
#       <td id="T_6889b_row4_col9" class="data row4 col9" >0.806600</td>
#       <td id="T_6889b_row4_col10" class="data row4 col10" >0.026800</td>
#       <td id="T_6889b_row4_col11" class="data row4 col11" >0.430900</td>
#       <td id="T_6889b_row4_col12" class="data row4 col12" >0.563600</td>
#       <td id="T_6889b_row4_col13" class="data row4 col13" >0.805300</td>
#       <td id="T_

# %%
# DM p-value heatmap (upper triangle only)
names  = list(garch_results.keys())
n_mods = len(names)
pvals  = dm_pval_df.values.astype(float)

# Mask lower triangle + diagonal (show upper triangle only)
mask       = np.tril(np.ones_like(pvals, dtype=bool))
pvals_plot = np.where(mask, np.nan, pvals)

fig, ax = plt.subplots(figsize=(max(8, n_mods * 0.65), max(6, n_mods * 0.55)), dpi=150)
im = ax.imshow(pvals_plot, cmap="RdYlGn_r", vmin=0, vmax=0.20, aspect="auto")
plt.colorbar(im, ax=ax, label="p-value", shrink=0.8)

ax.set_xticks(range(n_mods))
ax.set_xticklabels(names, rotation=45, ha="right", fontsize=7)
ax.set_yticks(range(n_mods))
ax.set_yticklabels(names, fontsize=7)
ax.set_title(f"DM test p-values ({TEST_LOSS} loss) — red = rejected H₀ at {DM_ALPHA}")

for i in range(n_mods):
    for j in range(i + 1, n_mods):
        v = pvals[i, j]
        if not np.isnan(v):
            sig = "*" if v < DM_ALPHA else ""
            ax.text(j, i, f"{v:.3f}{sig}", ha="center", va="center", fontsize=5.5,
                    color="white" if v < 0.05 else "black")

plt.tight_layout()
plt.show()

# %%
# DM statistics heatmap — colour based on p-value, numbers show DM statistic
names  = list(garch_results.keys())
n_mods = len(names)
pvals  = dm_pval_df.values.astype(float)
stats  = dm_stat_df.values.astype(float)

mask       = np.tril(np.ones_like(pvals, dtype=bool))
pvals_plot = np.where(mask, np.nan, pvals)
stats_plot = np.where(mask, np.nan, stats)

fig, ax = plt.subplots(figsize=(max(8, n_mods * 0.65), max(6, n_mods * 0.55)), dpi=150)
im = ax.imshow(pvals_plot, cmap="RdYlGn_r", vmin=0, vmax=0.20, aspect="auto")
plt.colorbar(im, ax=ax, label="p-value (colour scale)", shrink=0.8)

ax.set_xticks(range(n_mods))
ax.set_xticklabels(names, rotation=45, ha="right", fontsize=7)
ax.set_yticks(range(n_mods))
ax.set_yticklabels(names, fontsize=7)
ax.set_title(f"DM statistics ({TEST_LOSS} loss) — colour = p-value, numbers = MDM statistic, * p < {DM_ALPHA}")

for i in range(n_mods):
    for j in range(i + 1, n_mods):
        s = stats_plot[i, j]
        p = pvals_plot[i, j]
        if not np.isnan(s):
            sig = "*" if p < DM_ALPHA else ""
            ax.text(j, i, f"{s:.2f}{sig}", ha="center", va="center", fontsize=5.5,
                    color="white" if p < 0.05 else "black")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5.2 Model Confidence Set (MCS)
#
# Hansen, Lunde & Nason (2011). Sequential elimination of the worst model using the T_max statistic until the null of equal predictive accuracy cannot be rejected. Inference via stationary bootstrap (Politis & Romano 1994).
#
# Models with `mcs_pvalue > MCS_ALPHA` belong to the (1 − MCS_ALPHA) MCS.

# %%
mcs_result = mcs(
    garch_results,
    loss=TEST_LOSS,
    alpha=MCS_ALPHA,
    n_boot=N_BOOT,
    seed=RANDOM_SEED,
)
print(mcs_result)
print()
mcs_result.summary().style.map(
    lambda v: "background-color: #c8e6c9; font-weight: bold" if v is True else "",
    subset=["in_mcs"],
).format({"mcs_pvalue": "{:.4f}"})
# Out:
# MCSResult(alpha=0.05, loss='qlike', n_included=15, models=['GARCH-NORMAL', 'GARCH-T', 'GARCH-GED', 'GJR-GARCH-NORMAL', 'GJR-GARCH-T', 'GJR-GARCH-GED', 'EGARCH-NORMAL', 'EGARCH-T', 'EGARCH-GED', 'APARCH-NORMAL', 'APARCH-T', 'APARCH-GED', 'FIGARCH-NORMAL', 'FIGARCH-T', 'FIGARCH-GED'])
# <style type="text/css">
# #T_ccfe6_row0_col1, #T_ccfe6_row1_col1, #T_ccfe6_row2_col1, #T_ccfe6_row3_col1, #T_ccfe6_row4_col1, #T_ccfe6_row5_col1, #T_ccfe6_row6_col1, #T_ccfe6_row7_col1, #T_ccfe6_row8_col1, #T_ccfe6_row9_col1, #T_ccfe6_row10_col1, #T_ccfe6_row11_col1, #T_ccfe6_row12_col1, #T_ccfe6_row13_col1, #T_ccfe6_row14_col1 {
#   background-color: #c8e6c9;
#   font-weight: bold;
# }
# </style>
# <table id="T_ccfe6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccfe6_level0_col0" class="col_heading level0 col0" >mcs_pvalue</th>
#       <th id="T_ccfe6_level0_col1" class="col_heading level0 col1" >in_mcs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccfe6_level0_row0" class="row_heading level0 row0" >GARCH-NORMAL</th>
#       <td id="T_ccfe6_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_ccfe6_row0_col1" class="data row0 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row1" class="row_heading level0 row1" >GARCH-T</th>
#       <td id="T_ccfe6_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_ccfe6_row1_col1" class="data row1 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row2" class="row_heading level0 row2" >GARCH-GED</th>
#       <td id="T_ccfe6_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_ccfe6_row2_col1" class="data row2 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row3" class="row_heading level0 row3" >GJR-GARCH-NORMAL</th>
#       <td id="T_ccfe6_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_ccfe6_row3_col1" class="data row3 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row4" class="row_heading level0 row4" >GJR-GARCH-T</th>
#       <td id="T_ccfe6_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_ccfe6_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row5" class="row_heading level0 row5" >GJR-GARCH-GED</th>
#       <td id="T_ccfe6_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_ccfe6_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row6" class="row_heading level0 row6" >EGARCH-NORMAL</th>
#       <td id="T_ccfe6_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_ccfe6_row6_col1" class="data row6 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row7" class="row_heading level0 row7" >EGARCH-T</th>
#       <td id="T_ccfe6_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_ccfe6_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row8" class="row_heading level0 row8" >EGARCH-GED</th>
#       <td id="T_ccfe6_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_ccfe6_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row9" class="row_heading level0 row9" >APARCH-NORMAL</th>
#       <td id="T_ccfe6_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_ccfe6_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row10" class="row_heading level0 row10" >APARCH-T</th>
#       <td id="T_ccfe6_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_ccfe6_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row11" class="row_heading level0 row11" >APARCH-GED</th>
#       <td id="T_ccfe6_row11_col0" class="data row11 col0" >1.0000</td>
#       <td id="T_ccfe6_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row12" class="row_heading level0 row12" >FIGARCH-NORMAL</th>
#       <td id="T_ccfe6_row12_col0" class="data row12 col0" >1.0000</td>
#       <td id="T_ccfe6_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row13" class="row_heading level0 row13" >FIGARCH-T</th>
#       <td id="T_ccfe6_row13_col0" class="data row13 col0" >1.0000</td>
#       <td id="T_ccfe6_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccfe6_level0_row14" class="row_heading level0 row14" >FIGARCH-GED</th>
#       <td id="T_ccfe6_row14_col0" class="data row14 col0" >1.0000</td>
#       <td id="T_ccfe6_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5.2.1 MCS cross-check — arch.bootstrap.MCS (Sheppard)
#
# Independent verification using Kevin Sheppard's `arch.bootstrap.MCS` implementation (T_max statistic).
#
# **Interpretation:**
# - If both implementations agree (same models survive / same models all-included) → the result is consistent.
# - If both retain the full set with `squared` proxy but a subset survives with `garman_klass` → the earlier all-p=1 result was caused by a noisy proxy, not an implementation bug.
# - If the two implementations disagree for the same proxy → there is a bug in our custom MCS.

# %%
arch_mcs_result = arch_mcs(
    garch_results,
    loss=TEST_LOSS,
    size=MCS_ALPHA,
    n_boot=N_BOOT,
    seed=RANDOM_SEED,
)

print(f"arch.bootstrap.MCS — {TEST_LOSS} loss, alpha={MCS_ALPHA}")
print(f"Models in MCS: {arch_mcs_result['in_mcs'].sum()} / {len(arch_mcs_result)}")
print()

# Side-by-side comparison with our MCS
comparison = mcs_result.summary().rename(columns={"mcs_pvalue": "our_pvalue", "in_mcs": "our_in_mcs"})
comparison = comparison.join(
    arch_mcs_result.rename(columns={"mcs_pvalue": "arch_pvalue", "in_mcs": "arch_in_mcs"})
)
comparison.style.map(
    lambda v: "background-color: #c8e6c9; font-weight: bold" if v is True else "",
    subset=["our_in_mcs", "arch_in_mcs"],
).format({"our_pvalue": "{:.4f}", "arch_pvalue": "{:.4f}"})
# Out:
# arch.bootstrap.MCS — qlike loss, alpha=0.05
# Models in MCS: 15 / 15
# <style type="text/css">
# #T_500ef_row0_col1, #T_500ef_row0_col3, #T_500ef_row1_col1, #T_500ef_row1_col3, #T_500ef_row2_col1, #T_500ef_row2_col3, #T_500ef_row3_col1, #T_500ef_row3_col3, #T_500ef_row4_col1, #T_500ef_row4_col3, #T_500ef_row5_col1, #T_500ef_row5_col3, #T_500ef_row6_col1, #T_500ef_row6_col3, #T_500ef_row7_col1, #T_500ef_row7_col3, #T_500ef_row8_col1, #T_500ef_row8_col3, #T_500ef_row9_col1, #T_500ef_row9_col3, #T_500ef_row10_col1, #T_500ef_row10_col3, #T_500ef_row11_col1, #T_500ef_row11_col3, #T_500ef_row12_col1, #T_500ef_row12_col3, #T_500ef_row13_col1, #T_500ef_row13_col3, #T_500ef_row14_col1, #T_500ef_row14_col3 {
#   background-color: #c8e6c9;
#   font-weight: bold;
# }
# </style>
# <table id="T_500ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_500ef_level0_col0" class="col_heading level0 col0" >our_pvalue</th>
#       <th id="T_500ef_level0_col1" class="col_heading level0 col1" >our_in_mcs</th>
#       <th id="T_500ef_level0_col2" class="col_heading level0 col2" >arch_pvalue</th>
#       <th id="T_500ef_level0_col3" class="col_heading level0 col3" >arch_in_mcs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_500ef_level0_row0" class="row_heading level0 row0" >GARCH-NORMAL</th>
#       <td id="T_500ef_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_500ef_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_500ef_row0_col2" class="data row0 col2" >0.7460</td>
#       <td id="T_500ef_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row1" class="row_heading level0 row1" >GARCH-T</th>
#       <td id="T_500ef_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_500ef_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_500ef_row1_col2" class="data row1 col2" >0.9820</td>
#       <td id="T_500ef_row1_col3" class="data row1 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row2" class="row_heading level0 row2" >GARCH-GED</th>
#       <td id="T_500ef_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_500ef_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_500ef_row2_col2" class="data row2 col2" >0.8750</td>
#       <td id="T_500ef_row2_col3" class="data row2 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row3" class="row_heading level0 row3" >GJR-GARCH-NORMAL</th>
#       <td id="T_500ef_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_500ef_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_500ef_row3_col2" class="data row3 col2" >0.0995</td>
#       <td id="T_500ef_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row4" class="row_heading level0 row4" >GJR-GARCH-T</th>
#       <td id="T_500ef_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_500ef_row4_col1" class="data row4 col1" >True</td>
#       <td id="T_500ef_row4_col2" class="data row4 col2" >0.8570</td>
#       <td id="T_500ef_row4_col3" class="data row4 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row5" class="row_heading level0 row5" >GJR-GARCH-GED</th>
#       <td id="T_500ef_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_500ef_row5_col1" class="data row5 col1" >True</td>
#       <td id="T_500ef_row5_col2" class="data row5 col2" >0.5460</td>
#       <td id="T_500ef_row5_col3" class="data row5 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row6" class="row_heading level0 row6" >EGARCH-NORMAL</th>
#       <td id="T_500ef_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_500ef_row6_col1" class="data row6 col1" >True</td>
#       <td id="T_500ef_row6_col2" class="data row6 col2" >0.8105</td>
#       <td id="T_500ef_row6_col3" class="data row6 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row7" class="row_heading level0 row7" >EGARCH-T</th>
#       <td id="T_500ef_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_500ef_row7_col1" class="data row7 col1" >True</td>
#       <td id="T_500ef_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_500ef_row7_col3" class="data row7 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row8" class="row_heading level0 row8" >EGARCH-GED</th>
#       <td id="T_500ef_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_500ef_row8_col1" class="data row8 col1" >True</td>
#       <td id="T_500ef_row8_col2" class="data row8 col2" >0.8770</td>
#       <td id="T_500ef_row8_col3" class="data row8 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row9" class="row_heading level0 row9" >APARCH-NORMAL</th>
#       <td id="T_500ef_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_500ef_row9_col1" class="data row9 col1" >True</td>
#       <td id="T_500ef_row9_col2" class="data row9 col2" >0.5460</td>
#       <td id="T_500ef_row9_col3" class="data row9 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row10" class="row_heading level0 row10" >APARCH-T</th>
#       <td id="T_500ef_row10_col0" class="data row10 col0" >1.0000</td>
#       <td id="T_500ef_row10_col1" class="data row10 col1" >True</td>
#       <td id="T_500ef_row10_col2" class="data row10 col2" >0.9820</td>
#       <td id="T_500ef_row10_col3" class="data row10 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row11" class="row_heading level0 row11" >APARCH-GED</th>
#       <td id="T_500ef_row11_col0" class="data row11 col0" >1.0000</td>
#       <td id="T_500ef_row11_col1" class="data row11 col1" >True</td>
#       <td id="T_500ef_row11_col2" class="data row11 col2" >0.8570</td>
#       <td id="T_500ef_row11_col3" class="data row11 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row12" class="row_heading level0 row12" >FIGARCH-NORMAL</th>
#       <td id="T_500ef_row12_col0" class="data row12 col0" >1.0000</td>
#       <td id="T_500ef_row12_col1" class="data row12 col1" >True</td>
#       <td id="T_500ef_row12_col2" class="data row12 col2" >0.7275</td>
#       <td id="T_500ef_row12_col3" class="data row12 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row13" class="row_heading level0 row13" >FIGARCH-T</th>
#       <td id="T_500ef_row13_col0" class="data row13 col0" >1.0000</td>
#       <td id="T_500ef_row13_col1" class="data row13 col1" >True</td>
#       <td id="T_500ef_row13_col2" class="data row13 col2" >0.8770</td>
#       <td id="T_500ef_row13_col3" class="data row13 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_500ef_level0_row14" class="row_heading level0 row14" >FIGARCH-GED</th>
#       <td id="T_500ef_row14_col0" class="data row14 col0" >1.0000</td>
#       <td id="T_500ef_row14_col1" class="data row14 col1" >True</td>
#       <td id="T_500ef_row14_col2" class="data row14 col2" >0.8570</td>
#       <td id="T_500ef_row14_col3" class="data row14 col3" >True</td>
#     </tr>
#   </tbody>
# </table>
